# %% [markdown]
# # 00 — Setup MS-ZeroGAD on Colab
#
# Run this notebook **first** before any other notebook.
#
# **What it does:**
# 1. Mounts Google Drive
# 2. Verifies project structure
# 3. Installs dependencies
# 4. Tests GPU availability

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Set project root
#
# Adjust this path if your project is in a different location on Drive.

# %%
import sys, os

PROJECT_ROOT = '/content/drive/MyDrive/Project_GraphML/ms-zerogad'

assert os.path.exists(PROJECT_ROOT), f'Project not found at {PROJECT_ROOT}'
sys.path.insert(0, PROJECT_ROOT)
os.chdir(PROJECT_ROOT)

print(f'Project root: {PROJECT_ROOT}')
print(f'Working dir: {os.getcwd()}')
print()
print('Top-level contents:')
for item in sorted(os.listdir(PROJECT_ROOT)):
    print(f'  {item}')
# Out:
# Project root: /content/drive/MyDrive/Project_GraphML/ms-zerogad
# Working dir: /content/drive/MyDrive/Project_GraphML/ms-zerogad
#
# Top-level contents:
#   README.md
#   checkpoints
#   configs
#   ms_zerogad
#   notebooks
#   requirements.txt
#   results
#   scripts

# %% [markdown]
# ## 3. Install dependencies

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 4. Verify imports

# %%
import torch
import numpy as np
import scipy
import sklearn

print(f'PyTorch:      {torch.__version__}')
print(f'NumPy:        {np.__version__}')
print(f'SciPy:        {scipy.__version__}')
print(f'scikit-learn: {sklearn.__version__}')

# CUDA check
print(f'\nCUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'Device: {torch.cuda.get_device_name(0)}')
    print(f'Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2152/2487580718.py", line 1, in <cell line: 0>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1504, in _get_spec
# ...

# %% [markdown]
# ## 5. Verify project package

# %%
from ms_zerogad.modules.unification import GlobalUnification
from ms_zerogad.modules.clustering import RFFClustering
from ms_zerogad.modules.supergraph import build_super_graph
from ms_zerogad.modules.scoring import NodeNeutralizedScoringModule
from ms_zerogad.pipeline.multipass import MultiPassPipeline
from ms_zerogad.pipeline.aggregation import aggregate_scores
from ms_zerogad.data.loader import load_graph_dataset, dataset_info, print_dataset_info
from ms_zerogad.training.train import train
from ms_zerogad.evaluation.metrics import evaluate_pipeline, evaluate_per_pass

print('All imports successful.')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2152/4044980003.py", line 1, in <cell line: 0>
#     from ms_zerogad.modules.unification import GlobalUnification
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
# ...

# %% [markdown]
# ## Setup complete
#
# If all cells ran without errors, you can proceed to:
#
# - `01_test_dataloader.ipynb` to verify dataset loading
# - `07_train.ipynb` to start training
# - `08_evaluate.ipynb` for evaluation

# %%
# %run notebooks/01_test_dataloader.ipynb
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magics/execution.py", line 714, in run
#     filename = file_finder(fpath)
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/utils/path.py", line 109, in get_py_filename
#     raise IOError('File `%r` not found.' % name)
# OSError: File `'notebooks/01_test_dataloader.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
# ...

# %% [markdown]
# # Training ( Refer to notebook 07_train for more details )

# %%
# %run notebooks/07_train.ipynb
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/magics/execution.py", line 714, in run
#     filename = file_finder(fpath)
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/IPython/utils/path.py", line 109, in get_py_filename
#     raise IOError('File `%r` not found.' % name)
# OSError: File `'notebooks/07_train.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
# ...

# %%
from ms_zerogad.evaluation.metrics import evaluate_per_pass

results = evaluate_per_pass(pipeline, X, A, y, device=device)
# results['pass1']['auroc'], results['pass2']['auroc'], results['pass3']['auroc']
# results['aggregated']['auroc']
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2152/1028825835.py", line 1, in <cell line: 0>
#     from ms_zerogad.evaluation.metrics import evaluate_per_pass
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1322, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 1262, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1532, in find_spec
# ...

# %%
results['pass1']['auroc'], results['pass2']['auroc'], results['pass3']['auroc'], results['aggregated']['auroc']

# %% [markdown]
# # Evaluate ( Refer to notebook 08_evaluate for more details )

# %%
# %run notebooks/08_evaluate.ipynb

# %% [markdown]
# # Aggregation analysis ( Refer to notebook 09_aggregation_analysis for more details )

# %%
# %run notebooks/09_aggregation_analysis.ipynb
